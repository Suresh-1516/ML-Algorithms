# %%
import pandas as pd

# %%
df = pd.read_csv('placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
data = df[['cgpa','iq','placement']]

# %%
data
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(data[['cgpa','iq']],data['placement'],test_size=0.1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
pridicted = model.predict(xtest)

# %%
pridicted
# Out:
# array([1, 1, 1, 0, 0, 1, 1, 0, 1, 1])

# %%
ytest
# Out:
# 78    0
# 52    1
# 10    1
# 27    1
# 15    0
# 42    1
# 74    1
# 85    1
# 64    1
# 57    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,pridicted)
# Out:
# 0.7

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(xtrain, ytrain.values, clf=model, legend=2)
# Out:
# <Axes: >
